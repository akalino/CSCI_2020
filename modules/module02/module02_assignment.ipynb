# %% [markdown]
# # CSCI 2020 — Module 2 Assignment #2 (100 pts)
# ## Workout Routine Comparison Tool (Functions + Inputs + String Formatting)
#
# This notebook stubs out the assignment handout (M2A1). You will build a small program that compares two workout routines.
#
# Only edit cells marked **TODO**. Run the **CHECK** cells to verify your work.

# %%
# SETUP (do not edit)
from pathlib import Path

ROOT = Path.cwd()
print('Working directory:', ROOT)

# %% [markdown]
# ## Scenario
# You will compare two workout routines, **Routine A** and **Routine B**.
#
# Each routine has:
# - workout days per week (0–7)
# - minutes per workout day
# - intensity factor (1–5)
#
# You will use **inputs and functions** to compute weekly totals and a perceived effort score, then print a comparison report.

# %% [markdown]
# ## Part 1 — Input / Output Workflow (15 pts)
# Write a single function that captures and returns 4 inputs for a routine:
# - plan name (Routine A / Routine B)
# - days per week
# - minutes per workout
# - intensity factor
#
# You will call this function twice to capture Routine A and Routine B.

# %%
# TODO: Function to capture inputs for one routine
def get_routine_inputs() -> tuple:
    """Prompt the user for routine name, days/week, minutes/day, intensity (1-5).
    Return: (name, days, minutes, intensity)
    """
    # Your code here
    # Tip: input() returns strings; convert numeric inputs using int()
    pass

# %% [markdown]
# ## Part 2 — Function 1: Compute Total Workout Time (15 pts)
# Compute the total time per week (in minutes).

# %%
# TODO: Compute total minutes per week
def weekly_minutes(days_per_week: int, minutes_per_day: int) -> int:
    """Return total workout minutes in a single week."""
    # Your code here
    pass

# %% [markdown]
# ## Part 3 — Function 2: Weekly Effort Score (15 pts)
# Using your weekly total and intensity factor, compute a weekly effort score.
#
# **Recommended simple model:** `effort = weekly_minutes * intensity`.

# %%
# TODO: Compute weekly effort score
def weekly_effort_score(days_per_week: int, minutes_per_day: int, intensity: int) -> float:
    """Return a weekly effort score."""
    # Your code here
    pass

# %% [markdown]
# ## Part 4 — Function 3: Percent Difference (15 pts)
# Implement `percent_difference(effort1, effort2)`.
#
# The percent difference should be **relative to effort1**:
# ```
# pct = ((effort2 - effort1) / effort1) * 100
# ```

# %%
# TODO: Percent difference relative to effort1
def percent_difference(effort1: float, effort2: float) -> float:
    """Return the percent difference between effort1 and effort2, relative to effort1."""
    # Your code here
    # Tip: consider what happens if effort1 == 0
    pass

# %% [markdown]
# ## Part 5 — Function 4: Generate the Comparison Report (25 pts)
# Generate and print a report containing:
# - Routine A summary: name, days/week, minutes/day, intensity
# - Routine B summary on a new line
# - A comparison line stating percent difference in effort score (rounded to 1 decimal place)
#
# Hint: use `.format(...)` for strings.

# %%
# TODO: Generate and print the report
def print_comparison_report(r1: tuple, r2: tuple) -> None:
    """Print a formatted comparison report.
    Each routine tuple is: (name, days, minutes, intensity)
    """
    # Your code here
    pass

# %% [markdown]
# ## Main workflow (run interactively)
# Call your input function twice and print the comparison report.

# %%
# TODO: Run the program (interactive)
# routine_a = get_routine_inputs()
# routine_b = get_routine_inputs()
# print_comparison_report(routine_a, routine_b)
print('Uncomment the lines above when you are ready to run interactively.')

# %% [markdown]
# ## Expected Output Test Case
# Use these inputs to test your program:
# - Routine A: 4 days/week, 30 minutes/day, intensity 3
# - Routine B: 2 days/week, 40 minutes/day, intensity 5
#
# Your report should look similar to:
# 1. `Routine A: 4, 30, 3`
# 2. `Routine B: 2, 40, 5`
# 3. `Routine A intensity is 120.0% different from Routine B`

# %% [markdown]
# ## CHECKS (do not edit)
# These checks assume:
# - `weekly_effort_score = weekly_minutes * intensity`
# - `percent_difference = ((eff2-eff1)/eff1)*100`

# %%
# CHECK 1: weekly_minutes
assert weekly_minutes(4, 30) == 120
assert weekly_minutes(2, 40) == 80
print('✅ weekly_minutes checks passed')

# %%
# CHECK 2: weekly_effort_score (minutes*intensity)
assert weekly_effort_score(4, 30, 3) == 360
assert weekly_effort_score(2, 40, 5) == 400
print('✅ weekly_effort_score checks passed')

# %%
# CHECK 3: percent_difference relative to effort1
pct = percent_difference(360, 400)
assert round(pct, 1) == 11.1
print('✅ percent_difference checks passed')

# %% [markdown]
# ## Deliverables (per handout)
# Turn in two files:
# 1) This notebook (`.ipynb`) or a `.py` file where your functions and calculations take place.
# 2) A report (200–300 words) describing:
#    1. What problems did you run into?
#    2. How did you resolve these problems?
#    3. What sanity checks did you run?
#    4. One readability decision you made.

# %% [markdown]
# ## Report (200–300 words)
# **Problems:**
#
# **Resolutions:**
#
# **Sanity checks:**
#
# **Readability decision:**
