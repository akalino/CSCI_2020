# %% [markdown]
# # CSCI 2020 — Module 7 Assignment #7 (100 pts)
# ## One Base Class + One Child Class (Inheritance)
#
# This is a **minimal** assignment. You will implement:
# - a base class `Notification`
# - a child class `EmailNotification(Notification)`
#
# Only edit cells marked **TODO**.

# %%
# SETUP (do not edit)
from pathlib import Path

ROOT = Path.cwd()
print('Working directory:', ROOT)

# %% [markdown]
# ## Part A — Base Class: `Notification` (30 pts)
# Implement the base class with:
# - `__init__(self, message, level='info')`
# - attributes: `self.message`, `self.level`
# - method: `format()` returning a string like: `[INFO] Your message here`
#
# Convention for this assignment:
# - store `level` internally in lowercase
# - display `level` in uppercase inside brackets

# %%
# TODO: Implement Notification
class Notification:
    def __init__(self, message: str, level: str = 'info'):
        # TODO
        pass

    def format(self) -> str:
        # TODO
        pass

# %% [markdown]
# ## Part B — Child Class: `EmailNotification(Notification)` (25 pts)
# Implement the child class with:
# - `__init__(self, message, recipient, level='info')`
# - call the parent constructor using `super().__init__(...)`
# - store new attribute: `self.recipient`

# %%
# TODO: Implement EmailNotification
class EmailNotification(Notification):
    def __init__(self, message: str, recipient: str, level: str = 'info'):
        # TODO: call parent init with super()
        # TODO: set self.recipient
        pass

# %% [markdown]
# ## Part C — Override `format()` (20 pts)
# Override `format()` in `EmailNotification` so it returns:
# `[INFO] (to: someone@example.com) Your message here`
#
# **Tip:** You may reuse the parent formatting by calling `super().format()` and then inserting the recipient.

# %%
# TODO: Add/override format() inside EmailNotification
# (Edit the class definition above. Put the method there.)
print('After you implement EmailNotification.format(), run the checks below.')

# %% [markdown]
# ## Part D — Demo (15 pts)
# Create one base object and one child object and print their formatted messages.

# %%
# TODO: Demo usage
# n = Notification('System started', level='info')
# e = EmailNotification('Disk space low', recipient='admin@example.com', level='warning')
# print(n.format())
# print(e.format())
pass

# %% [markdown]
# ## CHECKS (do not edit)
# These checks confirm correctness of the required behavior.

# %%
# CHECK 1: base class behavior
n = Notification('Hello', level='info')
assert n.message == 'Hello'
assert n.level == 'info'
assert n.format() == '[INFO] Hello'
print('✅ Notification checks passed')

# %%
# CHECK 2: child class init + super + recipient
e = EmailNotification('Hello', recipient='someone@example.com', level='info')
assert e.message == 'Hello'
assert e.level == 'info'
assert e.recipient == 'someone@example.com'
print('✅ EmailNotification init checks passed')

# %%
# CHECK 3: override format includes recipient
out = e.format()
assert out.startswith('[INFO]'), out
assert '(to: someone@example.com)' in out, out
assert out.endswith('Hello'), out
print('✅ EmailNotification.format() override checks passed')

# %% [markdown]
# ## Reflection (10 pts) — 100–150 words
# 1) What did inheritance help you avoid duplicating?
# 2) What was confusing about `self` or `super()` (if anything)?

# %% [markdown]
# **Response:**
