# %% [markdown]
# # CSCI 2020 — Module 4
# ## Assignment — Module 4 Vending Machine (HW4)
#
# Run this notebook top-to-bottom.

# %%
# SETUP (do not edit)
from pathlib import Path

ROOT = Path.cwd()
MODULE_DIR = ROOT
DATA_DIR = MODULE_DIR / 'data'
OUTPUT_DIR = MODULE_DIR / 'output'
OUTPUT_DIR.mkdir(exist_ok=True)

print('Working directory:', ROOT)
print('Data dir exists:', DATA_DIR.exists(), '|', DATA_DIR)
print('Output dir:', OUTPUT_DIR)

# %% [markdown]
# # CSCI 2020 — Module 4 Assignment #4 (100 points)
#
# ## Scenario: The Vending Machine
# Build an interactive Python program that mimics a vending machine.
#
# Menu options:
# 1) View Menu
# 2) Buy Item (add to bag)
# 3) Checkout (print receipt + total)
# 4) Quit
#
# Your program should not crash if the user selects an invalid option or types nonsense characters.

# %% [markdown]
# ## Part 1 — Data setup (10 pts)
# Define at least five menu items and prices. Recommended: use a dictionary:
# - keys = item names
# - values = prices

# %%
# TODO: Define your menu dictionary here
# Example:
# menu = {
#     'Chips': 1.50,
#     'Soda': 2.00,
#     'Cookie': 1.25,
#     'Water': 1.00,
#     'Skittles': 2.25,
# }
menu = {}

# %% [markdown]
# ## Part 2 — Menu while loop (20 pts)
# Use a while loop to display the options. Loop ends when user selects Quit.
# Invalid menu choices should print a message and re-prompt.

# %% [markdown]
# ## Part 3 — Buy Item workflow (25 pts)
# When user selects Buy Item:
# 1) print menu (numbered list is fine)
# 2) ask for item selection (by number)
# 3) ask for quantity
#
# Use try/except to catch:
# - non-integer selection
# - non-integer quantity
# - quantity <= 0
#
# Store purchases in a 'bag':
# - list of names (duplicates allowed), OR
# - dict of item -> quantity (recommended)

# %% [markdown]
# ## Part 4 — Checkout workflow (25 pts)
# If bag is empty: print a message.
#
# If not empty:
# - Print a receipt line for each item: name, quantity, line total
# - Print grand total
# - Ask user to finalize purchase:
#   - yes -> print `Vending!`
#   - no -> print `Goodbye!`

# %% [markdown]
# ## Implementation (TODO)
# Write your program below. You may write helper functions.
# Recommended structure:
# - `print_menu(menu)`
# - `buy_item(menu, bag)`
# - `checkout(menu, bag)`
# - `main()` menu loop

# %%
# TODO: Implement your vending machine here

def print_menu(menu):
    # Your code here
    pass

def buy_item(menu, bag):
    # Your code here
    pass

def checkout(menu, bag):
    # Your code here
    pass

def main():
    # Your code here
    pass

# Uncomment to run interactively:
# main()
print('When ready, uncomment main() to run interactively.')

# %% [markdown]
# ## Deliverables (20 pts)
# Turn in:
# 1) this notebook (or a .py file)
# 2) a report (200–300 words) describing:
#    1. Problems you ran into
#    2. How you resolved them
#    3. What sanity checks you ran
#    4. One readability decision you made

# %% [markdown]
# ## Report (required)
# Write your 200–300 word report here (or in a separate file).
#
# **Problems:**
#
# **Resolutions:**
#
# **Sanity checks:**
#
# **Readability decision:**
